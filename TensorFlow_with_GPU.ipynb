# %% [markdown]
# <a href="https://colab.research.google.com/github/orhan-t/ELE608-Numerical-Method/blob/master/TensorFlow_with_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m task_jointUpsampling.main --load-weights weights_depth/x8_pac_weights_epoch_5000.pth \
                                    --download \
                                    --factor 8 \
                                    --model PacJointUpsample \
                                    --dataset NYUDepthV2 \
                                    --data-root data/nyu
# Out:
# ...
# 100% 2968535040/2972037809 [01:07<00:00, 35145328.69it/s]Traceback (most recent call last):
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/content/pacnet/task_jointUpsampling/main.py", line 348, in <module>
#     main()
#   File "/content/pacnet/task_jointUpsampling/main.py", line 291, in main
#     model.load_state_dict(torch.load(load_weights))
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 365, in load
#     f = open(f, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: 'weights_depth/x8_pac_weights_epoch_5000.pth'
# 2972041216it [01:14, 39660230.85it/s]

# %%
# !python -m task_jointUpsampling.main --factor 8 \
                                    --data-root data/nyu \
                                    --exp-root exp/nyu \
                                    --download \
                                    --dataset NYUDepthV2 \
                                    --epochs 5000 \
                                    --lr-steps 3500 4500
# Out:
# tcmalloc: large alloc 1228800000 bytes == 0x43122000 @  0x7fde2fdd21e7 0x7fde2d91241e 0x7fde2d962bdb 0x7fde2d915c98 0x551555 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588c8b 0x7fdde3137e5c 0x59478c 0x59fd0e 0x5576d8 0x50c19e 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50beb4
#
# Testing (#epochs=0)
# Average loss: 0.247728
# rmse: 2.055738
#
# Train Epoch 1 [100/1000 ( 10%)]	LR: 0.0001	Loss: 0.010295
# Train Epoch 1 [200/1000 ( 20%)]	LR: 0.0001	Loss: 0.013176
# Train Epoch 1 [300/1000 ( 30%)]	LR: 0.0001	Loss: 0.013308
# Train Epoch 1 [400/1000 ( 40%)]	LR: 0.0001	Loss: 0.013962
# Train Epoch 1 [500/1000 ( 50%)]	LR: 0.0001	Loss: 0.006922
# Train Epoch 1 [600/1000 ( 60%)]	LR: 0.0001	Loss: 0.004188
# Train Epoch 1 [700/1000 ( 70%)]	LR: 0.0001	Loss: 0.001487
# Train Epoch 1 [800/1000 ( 80%)]	LR: 0.0001	Loss: 0.003584
# Train Epoch 1 [900/1000 ( 90%)]	LR: 0.0001	Loss: 0.000576
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
